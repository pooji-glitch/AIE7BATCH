# %% [markdown]
# # LangSmith and Evaluation Overview with AI Makerspace
#
# Today we'll be looking at an amazing tool:
#
# [LangSmith](https://docs.smith.langchain.com/)!
#
# This tool will help us monitor, test, debug, and evaluate our LangChain applications - and more!
#
# We'll also be looking at a few Advanced Retrieval techniques along the way - and evaluate it using LangSmith!
#
# ✋BREAKOUT ROOM #2:
# - Task 1: Dependencies and OpenAI API Key
# - Task 2: LangGraph RAG
# - Task 3: Setting Up LangSmith
# - Task 4: Examining the Trace in LangSmith!
# - Task 5: Create Testing Dataset
# - Task 6: Evaluation

# %% [markdown]
# ## Task 1: Dependencies and OpenAI API Key
#
# We'll be using OpenAI's suite of models today to help us generate and embed our documents for our simple RAG system that leverages Loand Complaint data.

# %%
import os
import getpass

os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API Key:")

# %% [markdown]
# #### Asyncio Bug Handling

# %%
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ## Task #2: Create a Simple RAG Application Using LangGraph
#
# Let's remake our LangGraph RAG pipeline from the first notebook!

# %% [markdown]
# ## LangGraph Powered RAG
#
# First and foremost, LangChain provides a convenient way to store our chunks and their embeddings.
#
# It's called a `VectorStore`!
#
# We'll be using QDrant as our `VectorStore` today. You can read more about it [here](https://qdrant.tech/documentation/).
#
# Think of a `VectorStore` as a smart way to house your chunks and their associated embedding vectors. The implementation of the `VectorStore` also allows for smarter and more efficient search of our embedding vectors - as the method we used above would not scale well as we got into the millions of chunks.
#
# Otherwise, the process remains relatively similar under the hood!

# %% [markdown]
# ### Data Collection
#
# We'll be leveraging the `DirectoryLoader` to load our PDFs!

# %%
from langchain_community.document_loaders import DirectoryLoader
from langchain_community.document_loaders import PyMuPDFLoader

directory_loader = DirectoryLoader("data", glob="**/*.pdf", loader_cls=PyMuPDFLoader)

loan_knowledge_resources = directory_loader.load()

# %% [markdown]
# ### Chunking Our Documents

# %% [markdown]
# Let's do the same process as we did before with our `RecursiveCharacterTextSplitter` - but this time we'll use ~200 tokens as our max chunk size!

# %%
import tiktoken
from langchain.text_splitter import RecursiveCharacterTextSplitter

def tiktoken_len(text):
    tokens = tiktoken.encoding_for_model("gpt-4o").encode(
        text,
    )
    return len(tokens)

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 750,
    chunk_overlap = 0,
    length_function = tiktoken_len,
)
loan_knowledge_chunks = text_splitter.split_documents(loan_knowledge_resources)

# %%
len(loan_knowledge_chunks)
# Out:
# 375

# %% [markdown]
# Let's verify the process worked as intended by checking our max document length.

# %%
max_chunk_length = 0

for chunk in loan_knowledge_chunks:
  max_chunk_length = max(max_chunk_length, tiktoken_len(chunk.page_content))

print(max_chunk_length)
# Out:
# 742

# %% [markdown]
# Perfect! Now we can carry on to creating and storing our embeddings.

# %% [markdown]
# ### Embeddings and Vector Storage
#
# We'll use the `text-embedding-3-small` embedding model again - and `Qdrant` to store all our embedding vectors for easy retrieval later!

# %%
from langchain_community.vectorstores import Qdrant
from langchain_openai.embeddings import OpenAIEmbeddings

embedding_model = OpenAIEmbeddings(model="text-embedding-3-small")

qdrant_vectorstore = Qdrant.from_documents(
    documents=loan_knowledge_chunks,
    embedding=embedding_model,
    location=":memory:"
)

# %% [markdown]
# Now let's set up our retriever, just as we saw before, but this time using LangChain's simple `as_retriever()` method!

# %%
qdrant_retriever = qdrant_vectorstore.as_retriever()

# %% [markdown]
# #### Back to the Flow

# %% [markdown]
# We're ready to move to the next step!

# %% [markdown]
# ### Setting up our RAG
#
# We'll use the same LangGraph pipeline we created in the first notebook.
#
# Let's think through each part:
#
# 1. First we need to retrieve context
# 2. We need to pipe that context to our model
# 3. We need to parse that output
#
# Let's start by setting up our prompt again, just so it's fresh in our minds!

# %% [markdown]
# #### 🏗️ Activity #2:
#
# Complete the prompt so that your RAG application answers queries based on the context provided, but *does not* answer queries if the context is unrelated to the query.

# %%
from langchain_core.prompts import ChatPromptTemplate

HUMAN_TEMPLATE = """
#CONTEXT:
{context}

QUERY:
{query}

Use the provide context to answer the provided user query. Only use the provided context to answer the query. If you do not know the answer, or it's not contained in the provided context respond with "I don't know"
"""

chat_prompt = ChatPromptTemplate.from_messages([
    ("human", HUMAN_TEMPLATE)
])

# %%
from langchain_core.prompts import ChatPromptTemplate

HUMAN_TEMPLATE = """
You are a helpful assistant. Use only the information in the context below to answer the user's question.

# Context:
{context}

# Query:
{query}

If the answer is not found in the context, reply with: "I don't know."
"""

chat_prompt = ChatPromptTemplate.from_messages([
    ("human", HUMAN_TEMPLATE)
])

# %% [markdown]
# We'll set our Generator - `gpt-4.1-nano` in this case - below!

# %%
from langchain_openai import ChatOpenAI

openai_chat_model = ChatOpenAI(model="gpt-4.1-nano")

# %% [markdown]
# #### Our RAG Application
#
# Let's spin up the graph.

# %%
from langgraph.graph import START, StateGraph
from typing_extensions import TypedDict
from langchain_core.documents import Document
from langchain_core.output_parsers import StrOutputParser

class State(TypedDict):
  question: str
  context: list[Document]
  response: str

def retrieve(state: State) -> State:
  retrieved_docs = qdrant_retriever.invoke(state["question"])
  return {"context" : retrieved_docs}

def generate(state: State) -> State:
  generator_chain = chat_prompt | openai_chat_model | StrOutputParser()
  response = generator_chain.invoke({"query" : state["question"], "context" : state["context"]})
  return {"response" : response}

graph_builder = StateGraph(State)
graph_builder = graph_builder.add_sequence([retrieve, generate])
graph_builder.add_edge(START, "retrieve")
rag_graph = graph_builder.compile()

# %% [markdown]
# Let's get a visual understanding of our chain!

# %%
rag_graph

# %% [markdown]
# Let's test our chain out!

# %%
response = rag_graph.invoke({"question" : "Is applying for and securing a student loan in 2025 a terrible idea?"})

# %%
response["response"]
# Out:
# "I don't know."

# %%
for context in response["context"]:
  print("Context:")
  print(context.page_content[:100])
  print("----")
# Out:
# Context:
# student to earn that number of credits. For instance, if your school has a baccalaureate program tha
# ----
# Context:
# You must confirm that the borrower meets the definition of eligible borrower by doing the following:
# ----
# Context:
# Regardless of the counseling methods your school uses, it must document that the student received en
# ----
# Context:
# Pell Grant Lifetime Eligibility Used
# Before awarding a Pell Grant, you must check the COD common rec
# ----

# %% [markdown]
# Let's see if it can handle a query that is totally unrelated to the source documents.

# %%
response = rag_graph.invoke({"question" : "What is the airspeed velocity of an unladen swallow?"})

# %%
response["response"]
# Out:
# "I don't know."

# %% [markdown]
# ## Task 3: Setting Up LangSmith
#
# Now that we have a chain - we're ready to get started with LangSmith!
#
# We're going to go ahead and use the following `env` variables to get our Colab notebook set up to start reporting.
#
# If all you needed was simple monitoring - this is all you would need to do!

# %%
from uuid import uuid4

unique_id = uuid4().hex[0:8]


os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT"] = f"LangSmith - {unique_id}"

# %%
import os

api_key = os.environ.get("LANGCHAIN_API_KEY")
if api_key:
    print(f"LANGCHAIN_API_KEY is SET — starts with: {api_key[:5]}...")
else:
    print("LANGCHAIN_API_KEY is NOT SET")
# Out:
# LANGCHAIN_API_KEY is SET — starts with: lsv2_...

# %%
import os

print(f"LANGSMITH_TRACING: {os.environ.get('LANGSMITH_TRACING', 'NOT SET')}")
print(f"LANGSMITH_PROJECT: {os.environ.get('LANGSMITH_PROJECT', 'NOT SET')}")
print(f"LANGSMITH_API_KEY: {'SET' if os.environ.get('LANGCHAIN_API_KEY') else 'NOT SET'}")
# Out:
# LANGSMITH_TRACING: true
# LANGSMITH_PROJECT: LangSmith - 376a7336
# LANGSMITH_API_KEY: SET

# %% [markdown]
# ### LangSmith API
#
# In order to use LangSmith - you will need an API key. You can sign up for a free account on [LangSmith's homepage!](https://www.langchain.com/langsmith)
#
# Once you have created your account, Take the navigation option for `Settings` then `API Keys` to create an API key.

# %%
import os
import getpass

os.environ["LANGSMITH_API_KEY"] = getpass.getpass('Enter your LangSmith API key: ')

print(f"LANGSMITH_API_KEY: {'SET' if os.environ.get('LANGSMITH_API_KEY') else 'NOT SET'}")
# Out:
# LANGSMITH_API_KEY: SET

# %% [markdown]
# Let's test our our first generation!

# %%
result = rag_graph.invoke(
    {"question": "What is the maximum loan amount I can get from the government to go to school these days?"},
    config={"tags": ["Demo Run"]}
)

print(result["response"])
# Out:
# The maximum loan amount you can receive from the government depends on your student status and the type of program. For example, a dependent second-year undergraduate student can qualify for a maximum combined loan limit of $6,500 annually, with not more than $4,500 of that subsidized. The specific maximum limits vary based on your year in school and whether your program is standard or nonstandard term. For graduate and professional students, the total maximum is $138,500, with a subsidized limit of $65,500.

# %% [markdown]
# ## Task 4: Examining the Trace in LangSmith!
#
# Head on over to your LangSmith web UI to check out how the trace looks in LangSmith!

# %% [markdown]
# #### 🏗️ Activity #1:
#
# Include a screenshot of your trace and explain what it means.

# %% [markdown]
# ## Task 5: Loading Our Testing Set

# %%
# !git clone https://github.com/AI-Maker-Space/DataRepository.git
# Out:
# fatal: destination path 'DataRepository' already exists and is not an empty directory.

# %%
import pandas as pd

test_df = pd.read_csv("DataRepository/student_loan_rag_test_data.csv")

# %% [markdown]
# Now we can set up our LangSmith client - and we'll add the above created dataset to our LangSmith instance!
#
# > NOTE: Read more about this process [here](https://docs.smith.langchain.com/old/evaluation/faq/manage-datasets#create-from-list-of-values)

# %%
from langsmith import Client

client = Client()

dataset_name = "langsmith-student-loan-rag"

dataset = client.create_dataset(
    dataset_name=dataset_name, description="Student Loan RAG Test Questions"
)

for triplet in test_df.iterrows():
  triplet = triplet[1]
  client.create_example(
      inputs={"question" : triplet["question"], "context": triplet["context"]},
      outputs={"answer" : triplet["answer"]},
      dataset_id=dataset.id
  )
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/AIE7BATCH/04_Production_RAG/.venv/lib/python3.12/site-packages/langsmith/utils.py:154, in raise_for_status_with_text(response)
#     153 try:
# --> 154     response.raise_for_status()
#     155 except requests.HTTPError as e:
#
# File ~/AIE7BATCH/04_Production_RAG/.venv/lib/python3.12/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.smith.langchain.com/datasets
#
# The above exception was the direct cause of the following exception:
#
# HTTPError                                 Traceback (most recent call last)
# File ~/AIE7BATCH/04_Production_RAG/.venv/lib/python3.12/site-packages/langsmith/client.py:840, in Client.request_with_retries(self, method, pathname, request_kwargs, stop_after_attempt, retry_on, to_ignore, handle_response, _context, **kwargs)
#     834     response = self.session.request(
#     835         method,
#     836         _construct_url(self.api_url, pathname),
#     837         stream=False,
#     838         **request_kwargs,
#     839     )
# --> 840 ls_utils.raise_for_status_with_text(response)
#     841 return response
#
# File ~/AIE7BATCH/04_Production_RAG/.venv/lib/python3.12/site-packages/langsmith/utils.py:156, in raise_for_status_with_text(response)
#     155 except requests.HTTPError as e:
# --> 156     raise requests.HTTPError(str(e), response.text) from e  # type: ignore[call-arg]
#     157 except httpx.HTTPStatusError as e:
#
# HTTPError: [Errno 403 Client Error: Forbidden for url: https://api.smith.langchain.com/datasets] {"detail":"Forbidden"}
#
# During handling of the above exception, another exception occurred:
#
# LangSmithError                            Traceback (most recent call last)
# Cell In[125], line 7
#       3 client = Client()
#       5 dataset_name = "langsmith-student-loan-rag"
# ----> 7 dataset = client.create_dataset(
#       8     dataset_name=dataset_name, description="Student Loan RAG Test Questions"
#       9 )
#      11 for triplet in test_df.iterrows():
#      12   triplet = triplet[1]
#
# File ~/AIE7BATCH/04_Production_RAG/.venv/lib/python3.12/site-packages/langsmith/client.py:3435, in Client.create_dataset(self, dataset_name, description, data_type, inputs_schema, outputs_schema, transformations, metadata)
#    3432 if outputs_schema is not None:
#    3433     dataset["outputs_schema_definition"] = outputs_schema
# -> 3435 response = self.request_with_retries(
#    3436     "POST",
#    3437     "/datasets",
#    3438     headers={**self._headers, "Content-Type": "application/json"},
#    3439     data=_orjson.dumps(dataset),
#    3440 )
#    3441 ls_utils.raise_for_status_with_text(response)
#    3443 return ls_schemas.Dataset(
#    3444     **response.json(),
#    3445     _host_url=self._host_url,
#    3446     _tenant_id=self._get_optional_tenant_id(),
#    3447 )
#
# File ~/AIE7BATCH/04_Production_RAG/.venv/lib/python3.12/site-packages/langsmith/client.py:889, in Client.request_with_retries(self, method, pathname, request_kwargs, stop_after_attempt, retry_on, to_ignore, handle_response, _context, **kwargs)
#     885         raise ls_utils.LangSmithConflictError(
#     886             f"Conflict for {pathname}. {repr(e)}{_context}"
#     887         )
#     888     else:
# --> 889         raise ls_utils.LangSmithError(
#     890             f"Failed to {method} {pathname} in LangSmith"
#     891             f" API. {repr(e)}"
#     892         )
#     894 else:
#     895     raise ls_utils.LangSmithUserError(
#     896         f"Failed to {method} {pathname} in LangSmith API. {repr(e)}"
#     897     )
#
# LangSmithError: Failed to POST /datasets in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/datasets', '{"detail":"Forbidden"}')

# %% [markdown]
# ## Task 6: Evaluation
#
# Now we can run the evaluation!
#
# We'll need to start by preparing some custom data preparation functions to ensure our chain works with the expected inputs/outputs from the `evaluate` process in LangSmith.
#
# > NOTE: More reading on this available [here](https://docs.smith.langchain.com/how_to_guides/evaluation/evaluate_llm_application#evaluate-a-langchain-runnable)

# %%
def prepare_data_ref(run, example):
  return {
      "prediction" : run.outputs["response"],
      "reference" : example.outputs["answer"],
      "input" : example.inputs["question"]
  }

def prepare_data_noref(run, example):
  return {
      "prediction" : run.outputs["response"],
      "input" : example.inputs["question"]
  }

def prepare_context_ref(run, example):
  return {
      "prediction" : run.outputs["response"],
      "reference" : example.inputs["context"],
      "input" : example.inputs["question"]
  }

# %% [markdown]
# We'll be using a few custom evaluators to evaluate our pipeline, as well as a few "built in" methods!
#
# Check out the built-ins [here](https://docs.smith.langchain.com/reference/sdk_reference/langchain_evaluators)!

# %%
from langsmith.evaluation import LangChainStringEvaluator, evaluate

eval_llm = ChatOpenAI(model="gpt-4o-mini", tags=["eval_llm"])

cot_qa_evaluator = LangChainStringEvaluator("cot_qa",  config={"llm":eval_llm}, prepare_data=prepare_context_ref)

unlabeled_dopeness_evaluator = LangChainStringEvaluator(
    "criteria",
    config={
        "criteria" : {
            "dopeness" : "Is the answer to the question dope, meaning cool - awesome - and legit?"
        },
        "llm" : eval_llm,
    },
    prepare_data=prepare_data_noref
)

labeled_score_evaluator = LangChainStringEvaluator(
    "labeled_score_string",
    config={
        "criteria": {
            "accuracy": "Is the generated answer the same as the reference answer?"
        },
    },
    prepare_data=prepare_data_ref
)

base_rag_results = evaluate(
    rag_graph.invoke,
    data=dataset_name,
    evaluators=[
        cot_qa_evaluator,
        unlabeled_dopeness_evaluator,
        labeled_score_evaluator,
        ],
    experiment_prefix="Base RAG Evaluation"
)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/AIE7BATCH/04_Production_RAG/.venv/lib/python3.12/site-packages/langsmith/utils.py:154, in raise_for_status_with_text(response)
#     153 try:
# --> 154     response.raise_for_status()
#     155 except requests.HTTPError as e:
#
# File ~/AIE7BATCH/04_Production_RAG/.venv/lib/python3.12/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.smith.langchain.com/datasets?limit=1&name=langsmith-student-loan-rag
#
# The above exception was the direct cause of the following exception:
#
# HTTPError                                 Traceback (most recent call last)
# File ~/AIE7BATCH/04_Production_RAG/.venv/lib/python3.12/site-packages/langsmith/client.py:840, in Client.request_with_retries(self, method, pathname, request_kwargs, stop_after_attempt, retry_on, to_ignore, handle_response, _context, **kwargs)
#     834     response = self.session.request(
#     835         method,
#     836         _construct_url(self.api_url, pathname),
#     837         stream=False,
#     838         **request_kwargs,
#     839     )
# --> 840 ls_utils.raise_for_status_with_text(response)
#     841 return response
#
# File ~/AIE7BATCH/04_Production_RAG/.venv/lib/python3.12/site-packages/langsmith/utils.py:156, in raise_for_status_with_text(response)
#     155 except requests.HTTPError as e:
# --> 156     raise requests.HTTPError(str(e), response.text) from e  # type: ignore[call-arg]
#     157 except httpx.HTTPStatusError as e:
#
# HTTPError: [Errno 403 Client Error: Forbidden for url: https://api.smith.langchain.com/datasets?limit=1&name=langsmith-student-loan-rag] {"detail":"Forbidden"}
#
# During handling of the above exception, another exception occurred:
#
# LangSmithError                            Traceback (most recent call last)
# Cell In[41], line 28
#       7 unlabeled_dopeness_evaluator = LangChainStringEvaluator(
#       8     "criteria",
#       9     config={
#    (...)     15     prepare_data=prepare_data_noref
#      16 )
#      18 labeled_score_evaluator = LangChainStringEvaluator(
#      19     "labeled_score_string",
#      20     config={
#    (...)     25     prepare_data=prepare_data_ref
#      26 )
# ---> 28 base_rag_results = evaluate(
#      29     rag_graph.invoke,
#      30     data=dataset_name,
#      31     evaluators=[
#      32         cot_qa_evaluator,
#      33         unlabeled_dopeness_evaluator,
#      34         labeled_score_evaluator,
#      35         ],
#      36     experiment_prefix="Base RAG Evaluation"
#      37 )
#
# File ~/AIE7BATCH/04_Production_RAG/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py:423, in evaluate(target, data, evaluators, summary_evaluators, metadata, experiment_prefix, description, max_concurrency, num_repetitions, client, blocking, experiment, upload_results, error_handling, **kwargs)
#     421     _warn_once("'upload_results' parameter is in beta.")
#     422 logger.debug(f"Running evaluation over target system {target}...")
# --> 423 return _evaluate(
#     424     target,
#     425     data=data,
#     426     evaluators=cast(Optional[Sequence[EVALUATOR_T]], evaluators),
#     427     summary_evaluators=summary_evaluators,
#     428     metadata=metadata,
#     429     experiment_prefix=experiment_prefix,
#     430     description=description,
#     431     max_concurrency=max_concurrency,
#     432     num_repetitions=num_repetitions,
#     433     client=client,
#     434     blocking=blocking,
#     435     experiment=experiment,
#     436     upload_results=upload_results,
#     437     error_handling=error_handling,
#     438 )
#
# File ~/AIE7BATCH/04_Production_RAG/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py:1064, in _evaluate(target, data, evaluators, summary_evaluators, metadata, experiment_prefix, description, max_concurrency, num_repetitions, client, blocking, experiment, upload_results, error_handling)
#    1048 runs = None if _is_callable(target) else cast(Iterable[schemas.Run], target)
#    1049 experiment_, runs = _resolve_experiment(experiment, runs, client)
#    1051 manager = _ExperimentManager(
#    1052     data,
#    1053     client=client,
#    1054     metadata=metadata,
#    1055     experiment=experiment_ or experiment_prefix,
#    1056     description=description,
#    1057     num_repetitions=num_repetitions,
#    1058     # If provided, we don't need to create a new experiment.
#    1059     runs=runs,
#    1060     # Create or resolve the experiment.
#    1061     include_attachments=_include_attachments(target, evaluators),
#    1062     upload_results=upload_results,
#    1063     error_handling=error_handling,
# -> 1064 ).start()
#    1065 if cache_dir := ls_utils.get_cache_dir(None):
#    1066     cache_path = pathlib.Path(cache_dir) / f"{manager.dataset_id}.yaml"
#
# File ~/AIE7BATCH/04_Production_RAG/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py:1438, in _ExperimentManager.start(self)
#    1437 def start(self) -> _ExperimentManager:
# -> 1438     first_example = next(itertools.islice(self.examples, 1))
#    1439     project = self._get_project(first_example) if self._upload_results else None
#    1440     self._print_experiment_start(project, first_example)
#
# File ~/AIE7BATCH/04_Production_RAG/.venv/lib/python3.12/site-packages/langsmith/client.py:4903, in Client.list_examples(self, dataset_id, dataset_name, example_ids, as_of, splits, inline_s3_urls, offset, limit, metadata, filter, include_attachments, **kwargs)
#    4901     params["dataset"] = dataset_id
#    4902 elif dataset_name is not None:
# -> 4903     dataset_id = self.read_dataset(dataset_name=dataset_name).id
#    4904     params["dataset"] = dataset_id
#    4905 else:
#
# File ~/AIE7BATCH/04_Production_RAG/.venv/lib/python3.12/site-packages/langsmith/utils.py:142, in xor_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     136     invalid_group_names = [", ".join(arg_groups[i]) for i in invalid_groups]
#     137     raise ValueError(
#     138         "Exactly one argument in each of the following"
#     139         " groups must be defined:"
#     140         f" {', '.join(invalid_group_names)}"
#     141     )
# --> 142 return func(*args, **kwargs)
#
# File ~/AIE7BATCH/04_Production_RAG/.venv/lib/python3.12/site-packages/langsmith/client.py:3498, in Client.read_dataset(self, dataset_name, dataset_id)
#    3496 else:
#    3497     raise ValueError("Must provide dataset_name or dataset_id")
# -> 3498 response = self.request_with_retries(
#    3499     "GET",
#    3500     path,
#    3501     params=params,
#    3502 )
#    3503 result = response.json()
#    3504 if isinstance(result, list):
#
# File ~/AIE7BATCH/04_Production_RAG/.venv/lib/python3.12/site-packages/langsmith/client.py:889, in Client.request_with_retries(self, method, pathname, request_kwargs, stop_after_attempt, retry_on, to_ignore, handle_response, _context, **kwargs)
#     885         raise ls_utils.LangSmithConflictError(
#     886             f"Conflict for {pathname}. {repr(e)}{_context}"
#     887         )
#     888     else:
# --> 889         raise ls_utils.LangSmithError(
#     890             f"Failed to {method} {pathname} in LangSmith"
#     891             f" API. {repr(e)}"
#     892         )
#     894 else:
#     895     raise ls_utils.LangSmithUserError(
#     896         f"Failed to {method} {pathname} in LangSmith API. {repr(e)}"
#     897     )
#
# LangSmithError: Failed to GET /datasets in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/datasets?limit=1&name=langsmith-student-loan-rag', '{"detail":"Forbidden"}')

# %% [markdown]
# #### ❓Question #1:
#
# What conclusions can you draw about the above results?
#
# Describe in your own words what the metrics are expressing.
